# %%
import pandas as pd
import matplotlib
import plotly.express as px

df = pd.read_csv("vgsales.csv")

df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df.Publisher.value_counts().head(10).index.values.tolist()
# Out:
# ['Electronic Arts',
#  'Activision',
#  'Namco Bandai Games',
#  'Ubisoft',
#  'Konami Digital Entertainment',
#  'THQ',
#  'Nintendo',
#  'Sony Computer Entertainment',
#  'Sega',
#  'Take-Two Interactive']

# %%
df.Genre.value_counts().rename_axis("Genre").reset_index(name = "Releases")
# Out:
#            Genre  Releases
# 0         Action      3316
# 1         Sports      2346
# 2           Misc      1739
# 3   Role-Playing      1488
# 4        Shooter      1310
# 5      Adventure      1286
# 6         Racing      1249
# 7       Platform       886
# 8     Simulation       867
# 9       Fighting       848
# 10      Strategy       681
# 11        Puzzle       582

# %%
df.groupby("Publisher").sum().reset_index().sort_values(by="Global_Sales", ascending = False).head(5)
# Out:
#                        Publisher     Rank       Year  NA_Sales  EU_Sales  \
# 359                     Nintendo  2714164  1394666.0    816.87    418.74
# 138              Electronic Arts  7140412  2686562.0    595.07    371.27
# 21                    Activision  6368325  1938979.0    429.70    215.53
# 456  Sony Computer Entertainment  4105604  1367034.0    265.22    187.72
# 525                      Ubisoft  6964728  1843194.0    253.43    163.32
#
#      JP_Sales  Other_Sales  Global_Sales
# 359    455.42        95.33       1786.56
# 138     14.04       129.77       1110.32
# 21       6.54        75.34        727.46
# 456     74.10        80.45        607.50
# 525      7.50        50.26        474.72

# %%
from unicodedata import name


x = df.groupby(["Year", "Publisher"])["Name"].count().reset_index(name="Count")

x.groupby(["Publisher"]).sum().sort_values(by = "Count")
# Out:
#                                  Year  Count
# Publisher
# Locus                          1998.0      1
# Navarre Corp                   2008.0      1
# NDA Productions                2002.0      1
# Mystique                       1981.0      1
# Elite                          1996.0      1
# ...                               ...    ...
# Konami Digital Entertainment  60043.0    823
# Ubisoft                       46141.0    918
# Namco Bandai Games            66000.0    928
# Activision                    63974.0    966
# Electronic Arts               48107.0   1339
#
# [576 rows x 2 columns]

# %%
a = [publisher for publisher in df["Publisher"]]
x = list(set(a))

# %%
x = df.groupby(["Year", "Publisher"])["Name"].count().reset_index(name = "Count")

x = x[x.Publisher.isin(df.Publisher.value_counts().head(10).index.values.tolist())]

sales_year = df[['Year','NA_Sales','EU_Sales','JP_Sales','Other_Sales']].groupby(['Year'], as_index = False).sum()
sales_year
# Out:
#       Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0   1980.0     10.59      0.67      0.00         0.12
# 1   1981.0     33.40      1.96      0.00         0.32
# 2   1982.0     26.92      1.65      0.00         0.31
# 3   1983.0      7.76      0.80      8.10         0.14
# 4   1984.0     33.28      2.10     14.27         0.70
# 5   1985.0     33.73      4.74     14.56         0.92
# 6   1986.0     12.50      2.84     19.81         1.93
# 7   1987.0      8.46      1.41     11.63         0.20
# 8   1988.0     23.87      6.59     15.76         0.99
# 9   1989.0     45.15      8.44     18.36         1.50
# 10  1990.0     25.46      7.63     14.88         1.40
# 11  1991.0     12.76      3.95     14.78         0.74
# 12  1992.0     33.87     11.71     28.91         1.65
# 13  1993.0     15.12      4.65     25.33         0.89
# 14  1994.0     28.15     14.88     33.99         2.20
# 15  1995.0     24.82     14.90     45.75         2.64
# ...
